# %%
import cv2

# %%
image = cv2.imread('What-is-data-science-2.jpg')

# %%
image.shape
# Out:
# (503, 1000, 3)

# %% [markdown]
# here it shows that 503 is height of the image, 1000 is width of the image and 3 are color channels of the dimensions
