# %%
import cv2

# %%
image = cv2.imread('What-is-data-science-2.jpg')

# %%
image
# Out:
# array([[[11,  8, 10],
#         [ 4,  1,  3],
#         [ 4,  1,  3],
#         ...,
#         [43, 12, 33],
#         [43, 13, 32],
#         [42, 11, 32]],
#
#        [[11,  8, 10],
#         [ 4,  1,  3],
#         [ 4,  1,  3],
#         ...,
#         [46, 13, 34],
#         [45, 14, 35],
#         [44, 13, 34]],
#
#        [[11,  8, 10],
#         [ 4,  1,  3],
#         [ 4,  1,  3],
#         ...,
#         [48, 15, 36],
#         [47, 14, 35],
#         [47, 13, 37]],
#
#        ...,
#
#        [[19, 14, 16],
#         [13,  6,  9],
#         [13,  6,  9],
#         ...,
#         [19, 10, 13],
#         [19, 10, 13],
#         [19, 10, 13]],
#
#        [[19, 14, 16],
#         [13,  6,  9],
#         [13,  6,  9],
#         ...,
#         [19, 10, 13],
#         [21, 10, 13],
#         [17, 10, 13]],
#
#        [[19, 14, 16],
#         [13,  6,  9],
#         [13,  6,  9],
#         ...,
#         [21, 12, 15],
#         [30, 16, 20],
#         [23, 14, 17]]], dtype=uint8)
