# %%
import cv2

# %%
image = cv2.imread('What-is-data-science-2.jpg')

# %%
image.shape
# Out:
# (503, 1000, 3)

# %%
pt2  = (1000,503)
pt1 = (0,0)

# %%
drawwing_image = cv2.rectangle(img = image, pt1 =pt1 , pt2 = pt2, color = (0,255,0), thickness = 5)

# %%
cv2.imshow('Recangle Drawned Image', drawwing_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
