# %%
import cv2

# %%
image = cv2.imread('animate-social.webp')

# %%
blurred = cv2.medianBlur(src = image, ksize =15)

# %%
cv2.imshow('original image', image)
cv2.imshow('median blurred image', blurred)
cv2.waitKey(0)
cv2.destroyAllWindows()
